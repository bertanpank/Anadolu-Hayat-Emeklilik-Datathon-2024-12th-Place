# %%
import numpy as np
import pandas as pd
import gc
from xgboost import XGBClassifier
import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('data/train_preprocessed.csv', low_memory=False)
test = pd.read_csv('data/test_preprocessed.csv', low_memory=False)

# %%
train.head()
# Out:
#                                           MUSTERI_ID  LABEL  FLAG  \
# 0  59fd829fc435bf3ed0aa832ca0c89397e5197d8cc13518...     -1     5
# 1  040f50ce230c6c89d1ae9fa2d7187ad34212bd20623350...     -1     5
# 2  1372676078ce2f7863232bd9bd76b17dd65d07ebf4fb93...     -1     5
# 3  625516d0afe66e8c9c207ed98b18a0123f8528f152fa7a...     -1     5
# 4  84bd7c9b3526166b6ae1c1873d5f699d7a59232b55c445...     -1     5
#
#    PP_CINSIYET  PP_YAS  PP_MESLEK  IL  SORU_YATIRIM_KARAKTERI_RG  \
# 0            2   325.0  -0.939987  47                        0.0
# 1            2   541.0  -0.907518  34                        0.0
# 2            1   622.0  -0.986912  10                        0.0
# 3            1   495.0  -0.986912  63                        0.0
# 4            2    22.0  -0.986912  63                        0.0
#
#    SORU_MEDENI_HAL_RG  SORU_EGITIM_RG  ...  Regions_Akdeniz  \
# 0                46.0            46.0  ...            False
# 1               225.0           225.0  ...            False
# 2                97.0             0.0  ...            False
# 3               132.0             0.0  ...            False
# 4                20.0            20.0  ...            False
#
#    Regions_Doğu Anadolu  Regions_Ege  Regions_Güneydoğu Anadolu  \
# 0                 False        False                       True
# 1                 False        False                      False
# 2                 False         True                      False
# 3                 False        False                       True
# 4                 False        False                       True
#
#    Regions_Karadeniz  Regions_Marmara  Regions_Rare  Regions_İç Anadolu  \
# 0              False            False         False               False
# 1              False             True         False               False
# 2              False            False         False               False
# 3              False            False         False               False
# 4              False            False         False               False
#
#        PC_1      PC_2
# 0 -0.327933 -0.119758
# 1 -1.130885 -0.624636
# 2 -0.443118 -0.163713
# 3 -0.470187 -0.248751
# 4 -0.631859 -0.326021
#
# [5 rows x 129 columns]

# %% [markdown]
# **Veri seti çok dengesiz olduğu için(~97% - ~3%), ilk olarak `UA` sınıfını diğer sınıflardan ayırt etmeyi düşündük. Bunun için `UA` sınıfını 0, diğer sınıfları 1 olarak etiketleyerek `binary classification` modeli eğittik. Bu eğitim sırasında, accuracy kaybetmeden pozitif olan sınıfı yakalamak istediğimiz için `Recall - Accuracy` metriklerinin trade-off'una dikkat ettik.**

# %%
train.loc[train[train["LABEL"] == -1].index, "DummyLabel"] = 0
train.loc[train[train["LABEL"] != -1].index, "DummyLabel"] = 1
train.drop("LABEL", axis=1, inplace=True)

# %%
train.drop(["MUSTERI_ID"], axis=1, inplace=True)
test.drop(["MUSTERI_ID"], axis=1, inplace=True)

# %% [markdown]
# **Bu aşamada birden çok model denemesi yaptık ve en iyi sonuçları XGBoostClassifier ile aldık. O yüzden nihai `binary classification` modelimiz `XGBoostClassifier` oldu.**

# %% [markdown]
# **`Scale Pos Weight Parametresi:`** `UA` dışında kalan sınıfların ağırlıkları dengesizlikten dolayı eşit olmadığı için, `scale_pos_weight` parametresini kullanarak bu dengesizliği gidermeye çalıştık. Bu parametre, negatif (çoğunluk) sınıfın ağırlığını pozitif (azınlık) sınıfın ağırlığına oranlar. Bu sayede model, negatif sınıfı pozitif sınıf kadar önemli görmeye başlar. Bu parametreyi, `UA` sınıfının oranını diğer sınıfların oranına bölerek hesapladık.

# %%
# %%time
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from xgboost import XGBClassifier

recall_scores = []
acc_scores = []
X = train.drop("DummyLabel", axis=1)
y = train["DummyLabel"]

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Şimdi kf.split() metodunu doğru şekilde kullanalım
for i, (train_index, test_index) in enumerate(skf.split(X, y)):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum()
    model = XGBClassifier(
        scale_pos_weight = scale_pos_weight, 
        n_estimators=350,
        tree_method='gpu_hist',  
        device='cuda',
        n_jobs=-1,
        random_state=42
    )
    model.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=50)
    y_pred = model.predict(X_test)
    print(f"Fold {i+1}")
    print(f"Recall: {recall_score(y_test, y_pred)}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
    print(f"Precision: {precision_score(y_test, y_pred)}")
    print(f"F1: {f1_score(y_test, y_pred)}")
    recall_scores.append(recall_score(y_test, y_pred))
    acc_scores.append(accuracy_score(y_test, y_pred))

print(f"Recall: {np.mean(recall_scores)},  Accuracy: {np.mean(acc_scores)}")
# Out:
# [0]	validation_0-logloss:0.59021
# [50]	validation_0-logloss:0.33869
# [100]	validation_0-logloss:0.30561
# [150]	validation_0-logloss:0.28377
# [200]	validation_0-logloss:0.26609
# [250]	validation_0-logloss:0.25069
# [300]	validation_0-logloss:0.23717
# [349]	validation_0-logloss:0.22436
# Fold 1
# Recall: 0.7097744360902256
# Accuracy: 0.90754292147481
# Precision: 0.16236670106639148
# F1: 0.2642777155655095
# [0]	validation_0-logloss:0.59060
# [50]	validation_0-logloss:0.33713
# [100]	validation_0-logloss:0.30732
# [150]	validation_0-logloss:0.28594
# [200]	validation_0-logloss:0.26850
# [250]	validation_0-logloss:0.25310
# [300]	validation_0-logloss:0.23916
# [349]	validation_0-logloss:0.22673
# Fold 2
# Recall: 0.7152882205513784
# Accuracy: 0.9071911061075147
# Precision: 0.162658155705004
# F1: 0.2650445765230312
# [0]	validation_0-logloss:0.59076
# [50]	validation_0-logloss:0.33696
# [100]	validation_0-logloss:0.30420
# [150]	validation_0-logloss:0.28194
# [200]	validation_0-logloss:0.26475
# [250]	validation_0-logloss:0.24914
# [300]	validation_0-logloss:0.23589
# [349]	validation_0-logloss:0.22454
# Fold 3
# Recall: 0.712280701754386
# Accuracy: 0.9071911061075147
# Precision: 0.1621960963360347
# F1: 0.2642246188174042
# [0]	validation_0-logloss:0.58944
# [50]	validation_0-logloss:0.33289
# [100]	validation_0-logloss:0.30400
# [150]	validation_0-logloss:0.28294
# [200]	validation_0-logloss:0.26367
# [250]	validation_0-logloss:0.24891
# [300]	validation_0-logloss:0.23436
# [349]	validation_0-logloss:0.22154
# Fold 4
# Recall: 0.6842105263157895
# Accuracy: 0.9093840885636552
# Precision: 0.16130938312455684
# F1: 0.26106914028880174
# [0]	validation_0-logloss:0.59025
# [50]	validation_0-logloss:0.33748
# [100]	validation_0-logloss:0.30637
# [150]	validation_0-logloss:0.28446
# [200]	validation_0-logloss:0.26589
# [250]	validation_0-logloss:0.25086
# [300]	validation_0-logloss:0.23641
# [349]	validation_0-logloss:0.22565
# Fold 5
# Recall: 0.7147869674185464
# Accuracy: 0.9063819307627358
# Precision: 0.16131221719457015
# F1: 0.2632210429164744
# [0]	validation_0-logloss:0.58994
# [50]	validation_0-logloss:0.33264
# [100]	validation_0-logloss:0.30345
# [150]	validation_0-logloss:0.28310
# [200]	validation_0-logloss:0.26501
# [250]	validation_0-logloss:0.24974
# [300]	validation_0-logloss:0.23460
# [349]	validation_0-logloss:0.22165
# Fold 6
# Recall: 0.6942355889724311
# Accuracy: 0.9100525377615161
# Precision: 0.1640023682652457
# F1: 0.2653256704980843
# [0]	validation_0-logloss:0.58929
# [50]	validation_0-logloss:0.33336
# [100]	validation_0-logloss:0.30009
# [150]	validation_0-logloss:0.27736
# [200]	validation_0-logloss:0.26038
# [250]	validation_0-logloss:0.24543
# [300]	validation_0-logloss:0.23136
# [349]	validation_0-logloss:0.22024
# Fold 7
# Recall: 0.6802005012531328
# Accuracy: 0.9095248147105732
# Precision: 0.16089637182831396
# F1: 0.2602358807172308
# [0]	validation_0-logloss:0.59008
# [50]	validation_0-logloss:0.33399
# [100]	validation_0-logloss:0.29967
# [150]	validation_0-logloss:0.27831
# [200]	validation_0-logloss:0.26185
# [250]	validation_0-logloss:0.24552
# [300]	validation_0-logloss:0.23149
# [349]	validation_0-logloss:0.21892
# Fold 8
# Recall: 0.6932330827067669
# Accuracy: 0.9123041561122056
# Precision: 0.16765668565886774
# F1: 0.2700117141741507
# [0]	validation_0-logloss:0.59086
# [50]	validation_0-logloss:0.33681
# [100]	validation_0-logloss:0.30486
# [150]	validation_0-logloss:0.28258
# [200]	validation_0-logloss:0.26546
# [250]	validation_0-logloss:0.24929
# [300]	validation_0-logloss:0.23517
# [349]	validation_0-logloss:0.22371
# Fold 9
# Recall: 0.7112781954887218
# Accuracy: 0.908211370672671
# Precision: 0.16366782006920416
# F1: 0.26610407876230663
# [0]	validation_0-logloss:0.58913
# [50]	validation_0-logloss:0.32889
# [100]	validation_0-logloss:0.30085
# [150]	validation_0-logloss:0.27901
# [200]	validation_0-logloss:0.25821
# [250]	validation_0-logloss:0.24413
# [300]	validation_0-logloss:0.23115
# [349]	validation_0-logloss:0.21834
# Fold 10
# Recall: 0.7301905717151455
# Accuracy: 0.9099342097547818
# Precision: 0.16934170737380785
# F1: 0.27492447129909364
# Recall: 0.7045478792266524,  Accuracy: 0.9087718242027979
# CPU times: total: 8min 26s
# Wall time: 5min 12s

# %%
gc.collect()
# Out:
# 195

# %% [markdown]
# **Prediction yapıyoruz.**

# %%
pred = model.predict(test)

# %%
test = pd.concat([test, pd.Series(pred, name="DummyLabel")], axis=1)

# %%
test.head()
# Out:
#    FLAG  PP_CINSIYET  PP_YAS  PP_MESLEK    IL  SORU_YATIRIM_KARAKTERI_RG  \
# 0    11            2   467.0  -0.926782   1.0                        0.0
# 1    11            1   658.0  -0.926782  54.0                        0.0
# 2    11            1   634.0  -0.963381  48.0                        0.0
# 3    11            2   638.0  -0.992338  67.0                        0.0
# 4    11            1    80.0  -0.965346  34.0                        0.0
#
#    SORU_MEDENI_HAL_RG  SORU_EGITIM_RG  SORU_GELIR_CVP  SORU_GELIR_RG  ...  \
# 0               101.0             0.0          3000.0          101.0  ...
# 1               112.0           112.0          2800.0          112.0  ...
# 2               219.0           219.0          2000.0          219.0  ...
# 3               208.0           208.0             0.0          208.0  ...
# 4                 4.0             4.0             0.0            0.0  ...
#
#    Regions_Doğu Anadolu  Regions_Ege  Regions_Güneydoğu Anadolu  \
# 0                 False        False                      False
# 1                 False        False                      False
# 2                 False         True                      False
# 3                 False        False                      False
# 4                 False        False                      False
#
#    Regions_Karadeniz  Regions_Marmara  Regions_Rare  Regions_İç Anadolu  \
# 0              False            False         False               False
# 1              False             True         False               False
# 2              False            False         False               False
# 3               True            False         False               False
# 4              False             True         False               False
#
#        PC_1      PC_2  DummyLabel
# 0  0.208574 -0.442149           0
# 1 -0.314349 -0.039449           0
# 2 -0.602051  0.693810           0
# 3 -0.494246 -0.248365           0
# 4 -0.631607 -0.330536           0
#
# [5 rows x 128 columns]

# %%
test['DummyLabel'].value_counts(normalize=True)
# Out:
# DummyLabel
# 0    0.868513
# 1    0.131487
# Name: proportion, dtype: float64

# %% [markdown]
# **Şimdi `1` olarak tahmin ettiğimiz azınlık sınıflar için model geliştirdik.**

# %%
train = pd.read_csv('data/train_preprocessed.csv', low_memory=False)

# %%
train = train[train["LABEL"] != -1]

# %% [markdown]
# **Test setinde trend değişim ihtimali olduğunu düşündüğümüz içim modelimizde `FLAG` özelliğini kullanmak istemedik.**

# %%
train.drop(columns=['MUSTERI_ID', 'FLAG'], inplace=True) 
test.drop(columns=['FLAG'], inplace=True)

# %%
train['LABEL'] = train['LABEL'].astype(int)

# %%
# %%time
from autogluon.tabular import TabularDataset, TabularPredictor
import autogluon.common as ag
from autogluon.common import space
from custom_metrics import weighted_f1_scorer

time_limit = 3600*10

automl = TabularPredictor(label='LABEL', problem_type='multiclass',
                          eval_metric=weighted_f1_scorer
                          )

automl.fit(train, presets='best_quality', time_limit=time_limit, num_bag_folds=5, num_bag_sets=0, num_stack_levels=1, dynamic_stacking=False, 
            included_model_types=['XGB', 'CAT', 'GBM', 'RF', 'XT'], ag_args_fit={'num_gpus': 1, 'num_cpus': 8},
            infer_limit_batch_size=10, 
           hyperparameters = {
              # 'GBM': [
              #     {'max_depth': 10, 'n_estimators': 10000},
              #     {'max_depth': 9, 'n_estimators': 10000},
              #     {'max_depth': 8, 'n_estimators': 10000},
              #     {'max_depth': 7, 'n_estimators': 10000},
              #     {'max_depth': 6, 'n_estimators': 10000},
              #     {'max_depth': 5, 'n_estimators': 10000},
              #     {'max_depth': 4, 'n_estimators': 10000},
              #     {'max_depth': 3, 'n_estimators': 10000},
              #     {'max_depth': 2, 'n_estimators': 10000},
              # ],
              'XGB': [
                  
                  # {'max_depth': 10, 'n_estimators': 10000},
                  # {'max_depth': 9, 'n_estimators': 10000},
                  # {'max_depth': 8, 'n_estimators': 10000},
                  # {'max_depth': 7, 'n_estimators': 10000},
                  {'max_depth': 6, 'n_estimators': 100000},
                  {'max_depth': 5, 'n_estimators': 100000},
                  {'max_depth': 4, 'n_estimators': 100000},
                  {'max_depth': 3, 'n_estimators': 100000},
                  {'max_depth': 2, 'n_estimators': 100000},
              ],
              'CAT': [
                  # {'depth': 10, 'iterations': 10000},
                  # {'depth': 9, 'iterations': 10000},
                  # {'depth': 8, 'iterations': 10000},
                  # {'depth': 7, 'iterations': 10000},
                  {'depth': 6, 'iterations': 100000},
                  {'depth': 5, 'iterations': 100000},
                  {'depth': 4, 'iterations': 100000}, 
                  {'depth': 3, 'iterations': 100000},
                  {'depth': 2, 'iterations': 100000},
              ],
              # 'XT': [
              #     {'max_depth': 10, 'n_estimators': 10000},
              #     {'max_depth': 9, 'n_estimators': 10000},
              #     {'max_depth': 8, 'n_estimators': 10000},
              #     {'max_depth': 7, 'n_estimators': 10000},
              #     {'max_depth': 6, 'n_estimators': 10000},
              #     {'max_depth': 5, 'n_estimators': 10000},
              #     {'max_depth': 4, 'n_estimators': 10000},
              #     {'max_depth': 3, 'n_estimators': 10000},
              #     {'max_depth': 2, 'n_estimators': 10000},
              # ],
              # 'RF': [
              #     {'max_depth': 10, 'n_estimators': 10000},
              #     {'max_depth': 9, 'n_estimators': 10000},
              #     {'max_depth': 8, 'n_estimators': 10000},
              #     {'max_depth': 7, 'n_estimators': 10000},
              #     {'max_depth': 6, 'n_estimators': 10000},
              #     {'max_depth': 5, 'n_estimators': 10000},
              #     {'max_depth': 4, 'n_estimators': 10000},
              #     {'max_depth': 3, 'n_estimators': 10000},
              #     {'max_depth': 2, 'n_estimators': 10000},
              # ],
              }
          )
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240605_065455"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=0
# Beginning AutoGluon training ... Time limit = 36000s
# AutoGluon will save models to "AutogluonModels\ag-20240605_065455"
# =================== System Info ===================
# AutoGluon Version:  1.1.1b20240426
# Python Version:     3.10.10
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          12
# Memory Avail:       7.32 GB / 15.42 GB (47.5%)
# Disk Space Avail:   556.95 GB / 931.51 GB (59.8%)
# ===================================================
# Train Data Rows:    19949
# Train Data Columns: 126
# Label Column:       LABEL
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 7
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7492.24 MB
# 	Train Data (Original)  Memory Usage: 14.52 MB (0.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 45 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 2): ['BU06', 'BU12']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 7): ['SON_AY_KATKI_ADET', 'BU04', 'BU05', 'BU14', 'BU15', 'HU01', 'HU02']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 7 | ['SON_AY_KATKI_ADET', 'BU04', 'BU05', 'BU14', 'BU15', ...]
# 	Types of features in original data (raw dtype, special dtypes):
# 		('bool', [])  : 35 | ['PP_UYRUK_1', 'PP_UYRUK_Rare', 'SORU_MEDENI_HAL_CVP_Divorced', 'SORU_MEDENI_HAL_CVP_Married', 'SORU_MEDENI_HAL_CVP_Rare', ...]
# 		('float', []) : 80 | ['PP_YAS', 'PP_MESLEK', 'SORU_YATIRIM_KARAKTERI_RG', 'SORU_MEDENI_HAL_RG', 'SORU_EGITIM_RG', ...]
# 		('int', [])   :  2 | ['PP_CINSIYET', 'IL']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 75 | ['PP_YAS', 'PP_MESLEK', 'SORU_YATIRIM_KARAKTERI_RG', 'SORU_MEDENI_HAL_RG', 'SORU_EGITIM_RG', ...]
# 		('int', [])       :  1 | ['IL']
# 		('int', ['bool']) : 41 | ['PP_CINSIYET', 'BU21', 'HU05', 'HU07', 'HU13', ...]
# 	1.0s = Fit runtime
# 	117 features in original data used to generate 117 features in processed data.
# 	Train Data (Processed) Memory Usage: 12.35 MB (0.2% of available memory)
# 	0.33ms	= Feature Preprocessing Time (1 row | 10 batch size)
# Data preprocessing and feature engineering runtime = 1.12s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'custom_weighted_f1'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'XGB': [{'max_depth': 6, 'n_estimators': 100000}, {'max_depth': 5, 'n_estimators': 100000}, {'max_depth': 4, 'n_estimators': 100000}, {'max_depth': 3, 'n_estimators': 100000}, {'max_depth': 2, 'n_estimators': 100000}],
# 	'CAT': [{'depth': 6, 'iterations': 100000}, {'depth': 5, 'iterations': 100000}, {'depth': 4, 'iterations': 100000}, {'depth': 3, 'iterations': 100000}, {'depth': 2, 'iterations': 100000}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Included models: ['XGB', 'CAT', 'GBM', 'RF', 'XT'] (Specified by `included_model_types`, all other model types will be skipped)
# 	The models types ['XT', 'GBM', 'RF'] are not present in the model list specified by the user and will be ignored:
# Fitting 10 L1 models ...
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 23993.25s of the 35998.88s of remaining time.
# Will use sequential fold fitting strategy because import of ray failed. Reason: ray==2.6.3 detected. 2.10.0 <= ray < 2.11.0 is required. You can use pip to install certain version of ray `pip install ray==2.10.0`
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	0.4012	 = Validation score   (custom_weighted_f1)
# 	108.95s	 = Training   runtime
# 	0.09s	 = Validation runtime
# 	1.48ms	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	1.48ms	 = Validation runtime (1 row | 10 batch size)
# 	0.296ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.296ms	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: CatBoost_2_BAG_L1 ... Training model for up to 23878.39s of the 35884.01s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	0.4023	 = Validation score   (custom_weighted_f1)
# 	97.6s	 = Training   runtime
# 	0.1s	 = Validation runtime
# 	0.011s	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.011s	 = Validation runtime (1 row | 10 batch size)
# 	2.281ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	2.281ms	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: CatBoost_3_BAG_L1 ... Training model for up to 23780.51s of the 35786.13s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	0.4028	 = Validation score   (custom_weighted_f1)
# 	99.78s	 = Training   runtime
# 	0.1s	 = Validation runtime
# 	1.47ms	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	1.47ms	 = Validation runtime (1 row | 10 batch size)
# 	0.294ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.294ms	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: CatBoost_4_BAG_L1 ... Training model for up to 23680.29s of the 35685.91s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	0.3892	 = Validation score   (custom_weighted_f1)
# 	89.31s	 = Training   runtime
# 	0.11s	 = Validation runtime
# 	1.47ms	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	1.47ms	 = Validation runtime (1 row | 10 batch size)
# 	0.294ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.294ms	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: CatBoost_5_BAG_L1 ... Training model for up to 23590.52s of the 35596.14s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	0.376	 = Validation score   (custom_weighted_f1)
# 	92.87s	 = Training   runtime
# 	0.13s	 = Validation runtime
# 	1.374ms	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	1.374ms	 = Validation runtime (1 row | 10 batch size)
# 	0.275ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.275ms	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 23496.98s of the 35502.6s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.4201	 = Validation score   (custom_weighted_f1)
# 	156.52s	 = Training   runtime
# 	1.0s	 = Validation runtime
# 	0.05s	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.05s	 = Validation runtime (1 row | 10 batch size)
# 	9.98ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	9.98ms	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: XGBoost_2_BAG_L1 ... Training model for up to 23338.79s of the 35344.41s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.4333	 = Validation score   (custom_weighted_f1)
# 	134.96s	 = Training   runtime
# 	0.95s	 = Validation runtime
# 	0.047s	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.047s	 = Validation runtime (1 row | 10 batch size)
# 	9.381ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	9.381ms	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: XGBoost_3_BAG_L1 ... Training model for up to 23202.15s of the 35207.78s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.4301	 = Validation score   (custom_weighted_f1)
# 	126.28s	 = Training   runtime
# 	1.09s	 = Validation runtime
# 	0.046s	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.046s	 = Validation runtime (1 row | 10 batch size)
# 	9.28ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	9.28ms	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: XGBoost_4_BAG_L1 ... Training model for up to 23073.99s of the 35079.62s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.4376	 = Validation score   (custom_weighted_f1)
# 	152.76s	 = Training   runtime
# 	1.24s	 = Validation runtime
# 	0.057s	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.057s	 = Validation runtime (1 row | 10 batch size)
# 	0.011s	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.011s	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: XGBoost_5_BAG_L1 ... Training model for up to 22918.99s of the 34924.61s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.4431	 = Validation score   (custom_weighted_f1)
# 	313.74s	 = Training   runtime
# 	1.94s	 = Validation runtime
# 	0.103s	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.103s	 = Validation runtime (1 row | 10 batch size)
# 	0.021s	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.021s	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 2399.32s of the 34606.96s of remaining time.
# 	Ensemble Weights: {'XGBoost_5_BAG_L1': 1.0}
# 	0.4431	 = Validation score   (custom_weighted_f1)
# 	2.08s	 = Training   runtime
# 	0.01s	 = Validation runtime
# 	0.03ms	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.103s	 = Validation runtime (1 row | 10 batch size)
# 	0.03ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.021s	 = Validation runtime (1 row | 10 batch size | REFIT)
# Included models: ['XGB', 'CAT', 'GBM', 'RF', 'XT'] (Specified by `included_model_types`, all other model types will be skipped)
# 	The models types ['XT', 'GBM', 'RF'] are not present in the model list specified by the user and will be ignored:
# Fitting 10 L2 models ...
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 34604.69s of the 34604.65s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	0.4321	 = Validation score   (custom_weighted_f1)
# 	47.45s	 = Training   runtime
# 	0.09s	 = Validation runtime
# 	2.025ms	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.323s	 = Validation runtime (1 row | 10 batch size)
# 	0.405ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.065s	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: CatBoost_2_BAG_L2 ... Training model for up to 34556.79s of the 34556.75s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	0.4332	 = Validation score   (custom_weighted_f1)
# 	37.45s	 = Training   runtime
# 	0.09s	 = Validation runtime
# 	0.011s	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.332s	 = Validation runtime (1 row | 10 batch size)
# 	2.234ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.066s	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: CatBoost_3_BAG_L2 ... Training model for up to 34518.99s of the 34518.94s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	0.4388	 = Validation score   (custom_weighted_f1)
# 	32.66s	 = Training   runtime
# 	0.09s	 = Validation runtime
# 	1.93ms	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.323s	 = Validation runtime (1 row | 10 batch size)
# 	0.386ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.065s	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: CatBoost_4_BAG_L2 ... Training model for up to 34485.93s of the 34485.88s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	0.4353	 = Validation score   (custom_weighted_f1)
# 	33.66s	 = Training   runtime
# 	0.09s	 = Validation runtime
# 	1.921ms	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.323s	 = Validation runtime (1 row | 10 batch size)
# 	0.384ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.065s	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: CatBoost_5_BAG_L2 ... Training model for up to 34451.64s of the 34451.6s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	0.4431	 = Validation score   (custom_weighted_f1)
# 	36.7s	 = Training   runtime
# 	0.1s	 = Validation runtime
# 	0.011s	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.332s	 = Validation runtime (1 row | 10 batch size)
# 	2.27ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.066s	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 34414.51s of the 34414.46s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.4415	 = Validation score   (custom_weighted_f1)
# 	117.84s	 = Training   runtime
# 	0.34s	 = Validation runtime
# 	0.011s	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.331s	 = Validation runtime (1 row | 10 batch size)
# 	2.108ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.066s	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: XGBoost_2_BAG_L2 ... Training model for up to 34295.84s of the 34295.79s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.4439	 = Validation score   (custom_weighted_f1)
# 	98.69s	 = Training   runtime
# 	0.41s	 = Validation runtime
# 	0.014s	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.335s	 = Validation runtime (1 row | 10 batch size)
# 	2.779ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.067s	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: XGBoost_3_BAG_L2 ... Training model for up to 34196.07s of the 34196.03s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.4406	 = Validation score   (custom_weighted_f1)
# 	78.95s	 = Training   runtime
# 	0.5s	 = Validation runtime
# 	0.014s	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.335s	 = Validation runtime (1 row | 10 batch size)
# 	2.778ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.067s	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: XGBoost_4_BAG_L2 ... Training model for up to 34116.06s of the 34116.02s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.436	 = Validation score   (custom_weighted_f1)
# 	75.49s	 = Training   runtime
# 	0.5s	 = Validation runtime
# 	0.017s	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.338s	 = Validation runtime (1 row | 10 batch size)
# 	3.5ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.068s	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: XGBoost_5_BAG_L2 ... Training model for up to 34039.38s of the 34039.34s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.4349	 = Validation score   (custom_weighted_f1)
# 	69.82s	 = Training   runtime
# 	0.57s	 = Validation runtime
# 	0.018s	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.339s	 = Validation runtime (1 row | 10 batch size)
# 	3.6ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.068s	 = Validation runtime (1 row | 10 batch size | REFIT)
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 3460.47s of the 33968.04s of remaining time.
# 	Ensemble Weights: {'XGBoost_2_BAG_L2': 1.0}
# 	0.4439	 = Validation score   (custom_weighted_f1)
# 	2.02s	 = Training   runtime
# 	0.01s	 = Validation runtime
# 	0.03ms	 = Validation runtime (1 row | 10 batch size | MARGINAL)
# 	0.335s	 = Validation runtime (1 row | 10 batch size)
# 	0.03ms	 = Validation runtime (1 row | 10 batch size | REFIT | MARGINAL)
# 	0.067s	 = Validation runtime (1 row | 10 batch size | REFIT)
# AutoGluon training complete, total runtime = 2034.16s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240605_065455")
# CPU times: total: 48min 32s
# Wall time: 33min 55s

# %%
automl.leaderboard()
# Out:
#                   model  score_val         eval_metric  pred_time_val  \
# 0      XGBoost_2_BAG_L2   0.443945  custom_weighted_f1       7.156369
# 1   WeightedEnsemble_L3   0.443945  custom_weighted_f1       7.163345
# 2     CatBoost_5_BAG_L2   0.443146  custom_weighted_f1       6.838387
# 3      XGBoost_5_BAG_L1   0.443143  custom_weighted_f1       1.938882
# 4   WeightedEnsemble_L2   0.443143  custom_weighted_f1       1.946871
# 5        XGBoost_BAG_L2   0.441537  custom_weighted_f1       7.077991
# 6      XGBoost_3_BAG_L2   0.440647  custom_weighted_f1       7.240001
# 7     CatBoost_3_BAG_L2   0.438840  custom_weighted_f1       6.827994
# 8      XGBoost_4_BAG_L1   0.437551  custom_weighted_f1       1.240052
# 9      XGBoost_4_BAG_L2   0.436006  custom_weighted_f1       7.241196
# 10    CatBoost_4_BAG_L2   0.435268  custom_weighted_f1       6.834010
# 11     XGBoost_5_BAG_L2   0.434902  custom_weighted_f1       7.314011
# 12     XGBoost_2_BAG_L1   0.433326  custom_weighted_f1       0.945830
# 13    CatBoost_2_BAG_L2   0.433168  custom_weighted_f1       6.830007
# 14      CatBoost_BAG_L2   0.432051  custom_weighted_f1       6.830136
# 15     XGBoost_3_BAG_L1   0.430084  custom_weighted_f1       1.085046
# 16       XGBoost_BAG_L1   0.420110  custom_weighted_f1       1.002989
# 17    CatBoost_3_BAG_L1   0.402826  custom_weighted_f1       0.101996
# 18    CatBoost_2_BAG_L1   0.402287  custom_weighted_f1       0.095960
# 19      CatBoost_BAG_L1   0.401213  custom_weighted_f1       0.092005
# 20    CatBoost_4_BAG_L1   0.389156  custom_weighted_f1       0.113225
# 21    CatBoost_5_BAG_L1   0.376008  custom_weighted_f1       0.126013
#
#        fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   1471.460238                0.414371          98.694752            2
# 1   1473.482795                0.006976           2.022557            3
# 2   1409.467266                0.096388          36.701779            2
# 3    313.739692                1.938882         313.739692            1
# 4    315.822878                0.007988           2.083186            2
# 5   1490.602757                0.335992         117.837271            2
# 6   1451.711408                0.498003          78.945922            2
# 7   1405.422011                0.085995          32.656525            2
# 8    152.759021                1.240052         152.759021            1
# 9   1448.252599                0.499198          75.487113            2
# 10  1406.421505                0.092012          33.656018            2
# 11  1442.584812                0.572012          69.819326            2
# 12   134.960058                0.945830         134.960058            1
# 13  1410.220231                0.088009          37.454745            2
# 14  1420.215964                0.088138          47.450477            2
# 15   126.277479                1.085046         126.277479            1
# 16   156.517185                1.002989         156.517185            1
# 17    99.780431                0.101996          99.780431            1
# 18    97.596511                0.095960          97.596511            1
# 19   108.951284                0.092005         108.951284            1
# 20    89.313315                0.113225          89.313315            1
# 21    92.870511                0.126013          92.870511            1
#
#     can_infer  fit_order
# 0        True         18
# 1        True         22
# 2        True         16
# 3        True         10
# 4        True         11
# 5        True         17
# 6        True         19
# 7        True         14
# 8        True          9
# 9        True         20
# 10       True         15
# 11       True         21
# 12       True          7
# 13       True         13
# 14       True         12
# 15       True          8
# 16       True          6
# 17       True          3
# 18       True          2
# 19       True          1
# 20       True          4
# 21       True          5

# %%
predictions = automl.predict(test[test["DummyLabel"] == 1].drop("DummyLabel", axis=1), model='WeightedEnsemble_L3')

# %%
test.loc[test[test["DummyLabel"] == 0].index, "LABEL"] = "UA"

test.loc[test[test["DummyLabel"] == 1].index, "LABEL"] = predictions

# %%
encoding_map = {'HU06': 0, 'HU07': 1, 'HU11': 2,
                'HU12': 3, 'HU14': 4, 'HU15': 5, 'HU19': 6,
                }

test["LABEL"] = test["LABEL"].map({v: k for k, v in encoding_map.items()})
test["LABEL"].fillna("UA", inplace=True)

# %%
submission = pd.read_csv("sample_submission.csv")
submission["LABEL"] = test["LABEL"]
submission.to_csv("submission.csv", index=False)

# %%
submission.LABEL.value_counts(normalize=True)
# Out:
# LABEL
# UA      0.868513
# HU14    0.091356
# HU07    0.025379
# HU06    0.010796
# HU19    0.002091
# HU12    0.001196
# HU11    0.000491
# HU15    0.000179
# Name: proportion, dtype: float64
